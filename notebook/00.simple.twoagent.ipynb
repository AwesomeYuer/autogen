# %%
# ! python -m pip install numpy

# ! python -m pip install flaml

! python -m pip install dotenv
# Out:
# Collecting dotenv
#   Using cached dotenv-0.0.5.tar.gz (2.4 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [83 lines of output]
#       /home/awesomeyuer/miniconda3/envs/autogen-debug-py311-env/lib/python3.11/site-packages/setuptools/__init__.py:84: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#       !!
#
#               ********************************************************************************
#               Requirements should be satisfied by a PEP 517 installer.
#               If you are using pip, you can try `pip install --use-pep517`.
#               ********************************************************************************
#
#       !!
#         dist.fetch_build_eggs(dist.setup_requires)
#         error: subprocess-exited-with-error
#
#         × python setup.py egg_info did not run successfully.
#         │ exit code: 1
#         ╰─> [17 lines of output]
#             Traceback (most recent call last):
#               File "<string>", line 2, in <module>
#               File "<pip-setuptools-caller>", line 14, in <module>
#               File "/tmp/pip-wheel-4udmljc3/distribute_ab1f95394c704c48858b18e682e19022/setuptools/__init__.py", line 2, in <module>
#                 from setuptools.extension import Extension, Library
#               File "/tmp/pip-wheel-4udmljc3/distribute_ab1f95394c704c48858b18e682e19022/setuptools/extension.py", line 5, in <module>
#                 from setuptools.dist import _get_unpatched
#               File "/tmp/pip-wheel-4udmljc3/distribute_ab1f95394c704c48858b18e682e19022/setuptools/dist.py", line 7, in <module>
#                 from setuptools.command.install import install
#               File "/tmp/pip-wheel-4udmljc3/distribute_ab1f95394c704c48858b18e682e19022/setuptools/command/__init__.py", line 8, in <module>
#                 from setuptools.command import install_scripts
#               File "/tmp/pip-wheel-4udmljc3/distribute_ab1f95394c704c48858b18e682e19022/setuptools/command/install_scripts.py", line 3, in <module>
#                 from pkg_resources import Distribution, PathMetadata, ensure_directory
#               File "/tmp/pip-wheel-4udmljc3/distribute_ab1f95394c704c48858b18e682e19022/pkg_resources.py", line 1518, in <module>
#                 register_loader_type(importlib_bootstrap.SourceFileLoader, DefaultProvider)
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#             AttributeError: module 'importlib._bootstrap' has no attribute 'SourceFileLoader'
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: metadata-generation-failed
#
#       × Encountered error while generating package metadata.
#       ╰─> See above for output.
#
#       note: This is an issue with the package mentioned above, not pip.
#       hint: See above for details.
#       Traceback (most recent call last):
#         File "/home/awesomeyuer/miniconda3/envs/autogen-debug-py311-env/lib/python3.11/site-packages/setuptools/installer.py", line 96, in _fetch_build_egg_no_warn
#           subprocess.check_call(cmd)
#         File "/home/awesomeyuer/miniconda3/envs/autogen-debug-py311-env/lib/python3.11/subprocess.py", line 413, in check_call
#           raise CalledProcessError(retcode, cmd)
#       subprocess.CalledProcessError: Command '['/home/awesomeyuer/miniconda3/envs/autogen-debug-py311-env/bin/python', '-m', 'pip', '--disable-pip-version-check', 'wheel', '--no-deps', '-w', '/tmp/tmpezdt64v_', '--quiet', 'distribute']' returned non-zero exit status 1.
#
#       The above exception was the direct cause of the following exception:
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-xwgpupac/dotenv_1946891ec1854a7f8d50e5b6b821753e/setup.py", line 13, in <module>
#           setup(name='dotenv',
#         File "/home/awesomeyuer/miniconda3/envs/autogen-debug-py311-env/lib/python3.11/site-packages/setuptools/__init__.py", line 106, in setup
#           _install_setup_requires(attrs)
#         File "/home/awesomeyuer/miniconda3/envs/autogen-debug-py311-env/lib/python3.11/site-packages/setuptools/__init__.py", line 79, in _install_setup_requires
#           _fetch_build_eggs(dist)
#         File "/home/awesomeyuer/miniconda3/envs/autogen-debug-py311-env/lib/python3.11/site-packages/setuptools/__init__.py", line 84, in _fetch_build_eggs
#           dist.fetch_build_eggs(dist.setup_requires)
#         File "/home/awesomeyuer/miniconda3/envs/autogen-debug-py311-env/lib/python3.11/site-packages/setuptools/dist.py", line 907, in fetch_build_eggs
#           return _fetch_build_eggs(self, requires)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/home/awesomeyuer/miniconda3/envs/autogen-debug-py311-env/lib/python3.11/site-packages/setuptools/installer.py", line 38, in _fetch_build_eggs
#           resolved_dists = pkg_resources.working_set.resolve(
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/home/awesomeyuer/miniconda3/envs/autogen-debug-py311-env/lib/python3.11/site-packages/pkg_resources/__init__.py", line 829, in resolve
#           dist = self._resolve_dist(
#                  ^^^^^^^^^^^^^^^^^^^
#         File "/home/awesomeyuer/miniconda3/envs/autogen-debug-py311-env/lib/python3.11/site-packages/pkg_resources/__init__.py", line 865, in _resolve_dist
#           dist = best[req.key] = env.best_match(
#                                  ^^^^^^^^^^^^^^^
#         File "/home/awesomeyuer/miniconda3/envs/autogen-debug-py311-env/lib/python3.11/site-packages/pkg_resources/__init__.py", line 1135, in best_match
#           return self.obtain(req, installer)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/home/awesomeyuer/miniconda3/envs/autogen-debug-py311-env/lib/python3.11/site-packages/pkg_resources/__init__.py", line 1147, in obtain
#           return installer(requirement)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#         File "/home/awesomeyuer/miniconda3/envs/autogen-debug-py311-env/lib/python3.11/site-packages/setuptools/installer.py", line 98, in _fetch_build_egg_no_warn
#           raise DistutilsError(str(e)) from e
#       distutils.errors.DistutilsError: Command '['/home/awesomeyuer/miniconda3/envs/autogen-debug-py311-env/bin/python', '-m', 'pip', '--disable-pip-version-check', 'wheel', '--no-deps', '-w', '/tmp/tmpezdt64v_', '--quiet', 'distribute']' returned non-zero exit status 1.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# from autogen import AssistantAgent, UserProxyAgent, config_list_from_json
import sys
sys.path.append("..")
from autogen import *

config_list = autogen.config_list_from_json(
    "OAI_CONFIG_LIST",
    filter_dict={
        # "model": ["gpt-4", "gpt-4-0314", "gpt4", "gpt-4-32k", "gpt-4-32k-0314", "gpt-4-32k-v0314"],
        "model": ["gpt-35-turbo-16k-dep-001"]
    },
)

# Load LLM inference endpoints from an env variable or a file
# See https://microsoft.github.io/autogen/docs/FAQ#set-your-api-endpoints
# and OAI_CONFIG_LIST_sample
# config_list = config_list_from_json(env_or_file="OAI_CONFIG_LIST")
assistant = autogen.AssistantAgent("assistant", llm_config={"config_list": config_list})
user_proxy = autogen.UserProxyAgent(
                                "user_proxy",
                                 human_input_mode="NEVER",
                                 max_consecutive_auto_reply=3,
                                code_execution_config={"work_dir": "coding"}
                            )

# user_proxy.initiate_chat(assistant, message="Plot a chart of NVDA and TESLA stock price change YTD.")


# the assistant receives a message from the user, which contains the task description
user_proxy.initiate_chat(
    assistant,
    message="""What date is today? Which big tech stock has the largest year-to-date gain this year? How much is the gain?""",
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /mnt/d/MyGitHub/autogen/notebook/00.simple.twoagent.ipynb Cell 2 line 4
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04.2-lts-2023-06-27/mnt/d/MyGitHub/autogen/notebook/00.simple.twoagent.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> import sys
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04.2-lts-2023-06-27/mnt/d/MyGitHub/autogen/notebook/00.simple.twoagent.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> sys.path.append("..")
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04.2-lts-2023-06-27/mnt/d/MyGitHub/autogen/notebook/00.simple.twoagent.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> from autogen import *
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04.2-lts-2023-06-27/mnt/d/MyGitHub/autogen/notebook/00.simple.twoagent.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> config_list = autogen.config_list_from_json(
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04.2-lts-2023-06-27/mnt/d/MyGitHub/autogen/notebook/00.simple.twoagent.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     "OAI_CONFIG_LIST",
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04.2-lts-2023-06-27/mnt/d/MyGitHub/autogen/notebook/00.simple.twoagent.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     filter_dict={
#    (...)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04.2-lts-2023-06-27/mnt/d/MyGitHub/autogen/notebook/00.simple.twoagent.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>     },
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04.2-lts-2023-06-27/mnt/d/MyGitHub/autogen/notebook/00.simple.twoagent.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> )
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04.2-lts-2023-06-27/mnt/d/MyGitHub/autogen/notebook/00.simple.twoagent.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> # Load LLM inference endpoints from an env variable or a file
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04.2-lts-2023-06-27/mnt/d/MyGitHub/autogen/notebook/00.simple.twoagent.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> # See https://microsoft.github.io/autogen/docs/FAQ#set-your-api-endpoints
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04.2-lts-2023-06-27/mnt/d/MyGitHub/autogen/notebook/00.simple.twoagent.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> # and OAI_CONFIG_LIST_sample
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04.2-lts-2023-06-27/mnt/d/MyGitHub/autogen/notebook/00.simple.twoagent.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> # config_list = config_list_from_json(env_or_file="OAI_CONFIG_LIST")
#
# File /mnt/d/MyGitHub/autogen/notebook/../autogen/__init__.py:3
#       1 import logging
#       2 from .version import __version__
# ----> 3 from .oai import *
#       4 from .agentchat import *
#       5 from .code_utils import DEFAULT_MODEL, FAST_MODEL
#
# File /mnt/d/MyGitHub/autogen/notebook/../autogen/oai/__init__.py:1
# ----> 1 from autogen.oai.completion import Completion, ChatCompletion
#       2 from autogen.oai.openai_utils import (
#       3     get_config_list,
#       4     config_list_gpt4_gpt35,
#    (...)
#       8     config_list_from_dotenv,
#       9 )
#      11 __all__ = [
#      12     "Completion",
#      13     "ChatCompletion",
#    (...)
#      19     "config_list_from_dotenv",
#      20 ]
#
# File /mnt/d/MyGitHub/autogen/notebook/../autogen/oai/completion.py:11
#       9 from flaml.tune.space import is_constant
#      10 from flaml.automl.logger import logger_formatter
# ---> 11 from .openai_utils import get_key
#      12 from collections import defaultdict
#      14 try:
#
# File /mnt/d/MyGitHub/autogen/notebook/../autogen/oai/openai_utils.py:7
#       5 from typing import List, Optional, Dict, Set, Union
#       6 import logging
# ----> 7 from dotenv import find_dotenv, load_dotenv
#      10 NON_CACHE_KEY = ["api_key", "api_base", "api_type", "api_version"]
#      13 def get_key(config):
#
# ModuleNotFoundError: No module named 'dotenv'
